# %%
from llama_index.core import SummaryIndex

from llama_index.llms.google_genai import GoogleGenAI
from llama_index.readers.web import SimpleWebPageReader
from IPython.display import Markdown, display
import os
from dotenv import load_dotenv 

load_dotenv()
# Out:
# True

# %%
documents = SimpleWebPageReader(html_to_text=True).load_data(
    ["https://docs.llamaindex.ai/en/stable/examples/tools/AgentQL_browser_agent/"]
)

llm = GoogleGenAI(
    model="gemini-2.0-flash",
    # api_key="some key",  # uses GOOGLE_API_KEY env var by default
)

# %%
documents[0]
# Out:
# Document(id_='https://docs.llamaindex.ai/en/stable/examples/tools/AgentQL_browser_agent/', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Skip to content\n\n[ ![logo](../../../_static/assets/LlamaSquareBlack.svg) ](../../..\n"LlamaIndex")\n\nLlamaIndex\n\nBuilding a Browser Agent with AgentQL\n\n  * [ Home ](../../..)\n  * [ Learn ](../../../understanding/)\n  * [ Use Cases ](../../../use_cases/)\n  * [ Examples ](../../)\n  * [ Component Guides ](../../../module_guides/)\n  * [ Advanced Topics ](../../../optimizing/production_rag/)\n  * [ API Reference ](../../../api_reference/)\n  * [ Open-Source Community ](../../../community/integrations/)\n  * [ LlamaCloud ](../../../llama_cloud/)\n\n[ ![logo](../../../_static/assets/LlamaSquareBlack.svg) ](../../..\n"LlamaIndex") LlamaIndex\n\n  * [ Home  ](../../..)\n\nHome\n\n    * [ High-Level Concepts  ](../../../getting_started/concepts/)\n    * [ Installation and Setup  ](../../../getting_started/installation/)\n    * [ How to read these docs  ](../../../getting_started/reading/)\n    * Starter Examples  Starter Examples \n      * [ Starter Tutorial (Using OpenAI)  ](../../../getting_started/starter_example/)\n      * [ Starter Tutorial (Using Local LLMs)  ](../../../getting_started/starter_example_local/)\n    * [ Discover LlamaIndex Video Series  ](../../../getting_started/discover_llamaindex/)\n    * [ Frequently Asked Questions (FAQ)  ](../../../getting_started/customization/)\n    * [ Starter Tools  ](../../../getting_started/starter_tools/)\n\nStarter Tools\n\n      * [ RAG CLI  ](../../../getting_started/starter_tools/rag_cli/)\n  * [ Learn  ](../../../understanding/)\n\nLearn\n\n    * [ Using LLMs  ](../../../understanding/using_llms/using_llms/)\n    * [ Building agents  ](../../../understanding/agent/)\n\nBuilding agents\n\n      * [ Using existing tools  ](../../../understanding/agent/tools/)\n      * [ Maintaining state  ](../../../understanding/agent/state/)\n      * [ Streaming output and events  ](../../../understanding/agent/streaming/)\n      * [ Human in the loop  ](../../../understanding/agent/human_in_the_loop/)\n      * [ Multi-agent workflows  ](../../../understanding/agent/multi_agent/)\n    * [ Building Workflows  ](../../../understanding/workflows/)\n\nBuilding Workflows\n\n      * [ A basic workflow  ](../../../understanding/workflows/basic_flow/)\n      * [ Branches and loops  ](../../../understanding/workflows/branches_and_loops/)\n      * [ Maintaining state  ](../../../understanding/workflows/state/)\n      * [ Streaming events  ](../../../understanding/workflows/stream/)\n      * [ Concurrent execution  ](../../../understanding/workflows/concurrent_execution/)\n      * [ Subclassing workflows  ](../../../understanding/workflows/subclass/)\n      * [ Nested workflows  ](../../../understanding/workflows/nested/)\n      * [ Observability  ](../../../understanding/workflows/observability/)\n      * [ Unbound syntax  ](../../../understanding/workflows/unbound_functions/)\n    * [ Building a RAG pipeline  ](../../../understanding/rag/)\n\nBuilding a RAG pipeline\n\n      * Loading & Ingestion  Loading & Ingestion \n        * [ Loading Data (Ingestion)  ](../../../understanding/loading/loading/)\n        * [ LlamaHub  ](../../../understanding/loading/llamahub/)\n        * [ Loading from LlamaCloud  ](../../../understanding/loading/llamacloud/)\n      * [ Indexing & Embedding  ](../../../understanding/indexing/indexing/)\n      * [ Storing  ](../../../understanding/storing/storing/)\n      * [ Querying  ](../../../understanding/querying/querying/)\n    * [ Structured Data Extraction  ](../../../understanding/extraction/)\n\nStructured Data Extraction\n\n      * [ Using Structured LLMs  ](../../../understanding/extraction/structured_llms/)\n      * [ Structured Prediction  ](. ...

# %%
index = SummaryIndex.from_documents(documents)

# %%
index

# %%
query_engine = index.as_query_engine(llm=llm)

# %%
response = query_engine.query("what is this query about")

# %%
response
# Out:
# Response(response='This document is a guide on how to build a browser agent using AgentQL and LlamaIndex. It explains how to use AgentQL tools for web interaction and data extraction, including setup, instantiation, and usage examples with agents and workflows.', source_nodes=[NodeWithScore(node=TextNode(id_='f9cddac1-0a87-4ceb-874f-96af5aad0dc9', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='https://docs.llamaindex.ai/en/stable/examples/tools/AgentQL_browser_agent/', node_type='4', metadata={}, hash='af8129572d48dbef7faa95d7a81f16baa659418bbef93de91b1fd66645811d35'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='4b6a2f4d-0113-4b62-8ca5-8624c7990760', node_type='1', metadata={}, hash='657e2ac781e223ee554895dbd3264830afa783f189443c1960d71b5bfdf26563')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Skip to content\n\n[ ![logo](../../../_static/assets/LlamaSquareBlack.svg) ](../../..\n"LlamaIndex")\n\nLlamaIndex\n\nBuilding a Browser Agent with AgentQL\n\n  * [ Home ](../../..)\n  * [ Learn ](../../../understanding/)\n  * [ Use Cases ](../../../use_cases/)\n  * [ Examples ](../../)\n  * [ Component Guides ](../../../module_guides/)\n  * [ Advanced Topics ](../../../optimizing/production_rag/)\n  * [ API Reference ](../../../api_reference/)\n  * [ Open-Source Community ](../../../community/integrations/)\n  * [ LlamaCloud ](../../../llama_cloud/)\n\n[ ![logo](../../../_static/assets/LlamaSquareBlack.svg) ](../../..\n"LlamaIndex") LlamaIndex\n\n  * [ Home  ](../../..)\n\nHome\n\n    * [ High-Level Concepts  ](../../../getting_started/concepts/)\n    * [ Installation and Setup  ](../../../getting_started/installation/)\n    * [ How to read these docs  ](../../../getting_started/reading/)\n    * Starter Examples  Starter Examples \n      * [ Starter Tutorial (Using OpenAI)  ](../../../getting_started/starter_example/)\n      * [ Starter Tutorial (Using Local LLMs)  ](../../../getting_started/starter_example_local/)\n    * [ Discover LlamaIndex Video Series  ](../../../getting_started/discover_llamaindex/)\n    * [ Frequently Asked Questions (FAQ)  ](../../../getting_started/customization/)\n    * [ Starter Tools  ](../../../getting_started/starter_tools/)\n\nStarter Tools\n\n      * [ RAG CLI  ](../../../getting_started/starter_tools/rag_cli/)\n  * [ Learn  ](../../../understanding/)\n\nLearn\n\n    * [ Using LLMs  ](../../../understanding/using_llms/using_llms/)\n    * [ Building agents  ](../../../understanding/agent/)\n\nBuilding agents\n\n      * [ Using existing tools  ](../../../understanding/agent/tools/)\n      * [ Maintaining state  ](../../../understanding/agent/state/)\n      * [ Streaming output and events  ](../../../understanding/agent/streaming/)\n      * [ Human in the loop  ](../../../understanding/agent/human_in_the_loop/)\n      * [ Multi-agent workflows  ](../../../understanding/agent/multi_agent/)\n    * [ Building Workflows  ](../../../understanding/workflows/)\n\nBuilding Workflows\n\n      * [ A basic workflow  ](../../../understanding/workflows/basic_flow/)\n      * [ Branches and loops  ](../../../understanding/workflows/branches_and_loops/)\n      * [ Maintaining state  ](../../../understanding/workflows/state/)\n      * [ Streaming events  ](../../../understanding/workflows/stream/)\n      * [ Concurrent execution  ](../../../understanding/workflows/concurrent_execution/)\n      * [ Subclassing workflows  ](../../../understanding/workflows/subclass/)\n      * [ Nested workflows  ](../../../understanding/workflows/nested/)\n      * [ Observability  ](../../../understanding/workflows/observability/)\n      * [ Unbound syntax  ](../../../understanding/workflows/unbound_functions/)\n    * [ Building a RAG pipeline  ](../../../understanding/rag/)\n\nBuilding a RAG pipeline\n\n      * Loading & Ingestion  Loading & Ingestion \n        * [ Loading Data (Ingestion)   ...
